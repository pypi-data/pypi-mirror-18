# %% [markdown]
# <small>*Notebook auto-generated from [``altair/examples/json/layer_line_color_rule.json``](../../altair/examples/json/layer_line_color_rule.json)*</small>
#
# # Altair Example: Layer Line Color Rule
#
# --

# %% [markdown]
# ## Load Dataset
# The data comes in the form of a Pandas Dataframe:

# %%
from altair import load_dataset
data = load_dataset("stocks")
data.head()
# Out:
#   symbol        date  price
# 0   MSFT  Jan 1 2000  39.81
# 1   MSFT  Feb 1 2000  36.35
# 2   MSFT  Mar 1 2000  43.22
# 3   MSFT  Apr 1 2000  28.37
# 4   MSFT  May 1 2000  25.45

# %% [markdown]
# ## Define Altair Specification

# %%
from altair import *  # Import the altair API

chart = LayeredChart(data,
    layers=[Chart().mark_line().encode(
            color='symbol:N',
            x='date:T',
            y='price:Q',
        ), Chart().mark_rule(
            opacity=0.5,
        ).encode(
            color='symbol:N',
            size=Size(
                value=2.0,
            ),
            y='mean(price):Q',
        )],
)

# %% [markdown]
# IPython rich display will invoke Vega-Lite:

# %%
chart
# Out:
# <div class="vega-embed" id="3f5fbe9c-b0d9-4409-adea-159e12e23275"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Output Vega-Lite Specification

# %% [markdown]
# Generate JSON dict, leaving data out:

# %%
chart.to_dict(data=False)
# Out:
# {'layers': [{'encoding': {'color': {'field': 'symbol', 'type': 'nominal'},
#     'x': {'field': 'date', 'type': 'temporal'},
#     'y': {'field': 'price', 'type': 'quantitative'}},
#    'mark': 'line'},
#   {'config': {'mark': {'opacity': 0.5}},
#    'encoding': {'color': {'field': 'symbol', 'type': 'nominal'},
#     'size': {'value': 2.0},
#     'y': {'aggregate': 'mean', 'field': 'price', 'type': 'quantitative'}},
#    'mark': 'rule'}]}
