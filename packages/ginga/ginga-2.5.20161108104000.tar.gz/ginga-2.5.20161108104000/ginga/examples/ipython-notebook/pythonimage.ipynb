# %%
from ginga import RGBImage

# %%
reload(RGBImage)
# Out:
# <module 'ginga.RGBImage' from '/home/eric/Git/Ginga/ginga/RGBImage.py'>

# %%
foo = RGBImage.RGBImage()

# %%
foo.load_file("/home/eric/Git/Ginga/ginga/icons/ginga-512x512.png")

# %%
buf = foo.get_buffer(format='jpeg')

# %%
len(buf)
# Out:
# 109121

# %%
from IPython.display import Image

# %%
Image(data=buf, format='jpeg', embed=True)
